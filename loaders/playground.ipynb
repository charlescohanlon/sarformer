# %%
import torch
from PIL import Image
from torchvision.transforms.v2 import PILToTensor

# %%
naip = Image.open("/home/charles/Dev/sarformer/NAIP_178423.tif", formats=("JPEG",))
dem = Image.open("/home/charles/Dev/sarformer/DEM_178423.tif")

# %%
nt = PILToTensor()(naip)
dt = PILToTensor()(dem)

# %%
combined = torch.cat((nt, dt), dim=0)
combined.shape
# Out:
# torch.Size([4, 512, 512])

# %%
combined[3, 128, 128]
# Out:
# tensor(795.8614)
