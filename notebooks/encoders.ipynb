# %%
import torch
import os

os.chdir("..") # to allow relative imports
from model.sarformer import *
from utils.sar_dataset import SARDataset

torch.set_printoptions(linewidth=10000000, threshold=300000000)

# %%
from torch.utils.data import DataLoader, random_split

batch_size = 2

dataset = SARDataset(
    root_path="/data/million-case",
    img_dir="topo",
    csv_file="all_data.csv",
    csv_delimeter="@",
    convert_time_features=True,
    text_max_tokens=512,
    text_mask_proportion=0.10,
    mm_objective=True,
)

train_set, test_set = random_split(dataset, [0.99, 0.01])
train_dataloader = DataLoader(train_set, batch_size, shuffle=True)
test_dataloader = DataLoader(test_set, batch_size)

# %%
img_tensor, text_tensor, text_mask, tabular_tensor = next(iter(train_dataloader))

# %%
model = SARFormer(mask_proportions={"swin": 0.662, "roberta": 0.75, "tabular": 0.75})
model(img_tensor, text_tensor, text_mask, tabular_tensor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 model = SARFormer(mask_proportions={"swin": 0.662, "roberta": 0.75, "tabular": 0.75})
# ----> 2 model(img_tensor, text_tensor, text_mask, tabular_tensor)
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Development/sarformer/model/sarformer.py:93, in SARFormer.forward(self, img_tensor, text_tensor, text_mask, tab_tensor)
#      91 def forward(self, img_tensor, text_tensor, text_mask, tab_tensor):
#      92     embed_img = self.swin_encoder(img_tensor)
# ---> 93     embed_text = self.roberta_encoder(text_tensor, text_mask)
#      94     embed_tab = self.tabular_encoder(tab_tensor)
#      96     # if mask proportions specified, forward() returns the masked input,
#      97     # the mask (except the text one), and the embeddings
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Development/sarformer/model/roberta_encoder.py:34, in RoBERTa.forward(self, x, mask)
#      31     masked_full_x = self.mask(x, mask)
#      33 # mask applied in HF model class
# ---> 34 x = self.model(x, attention_mask=mask)
#      36 if self.mask_proportion:
#      37     return masked_full_x, x
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:832, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     823 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     825 embedding_output = self.embeddings(
#     826     input_ids=input_ids,
#     827     position_ids=position_ids,
#    (...)
#     830     past_key_values_length=past_key_values_length,
#     831 )
# --> 832 encoder_outputs = self.encoder(
#     833     embedding_output,
#     834     attention_mask=extended_attention_mask,
#     835     head_mask=head_mask,
#     836     encoder_hidden_states=encoder_hidden_states,
#     837     encoder_attention_mask=encoder_extended_attention_mask,
#     838     past_key_values=past_key_values,
#     839     use_cache=use_cache,
#     840     output_attentions=output_attentions,
#     841     output_hidden_states=output_hidden_states,
#     842     return_dict=return_dict,
#     843 )
#     844 sequence_output = encoder_outputs[0]
#     845 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:521, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     510     layer_outputs = self._gradient_checkpointing_func(
#     511         layer_module.__call__,
#     512         hidden_states,
#    (...)
#     518         output_attentions,
#     519     )
#     520 else:
# --> 521     layer_outputs = layer_module(
#     522         hidden_states,
#     523         attention_mask,
#     524         layer_head_mask,
#     525         encoder_hidden_states,
#     526         encoder_attention_mask,
#     527         past_key_value,
#     528         output_attentions,
#     529     )
#     531 hidden_states = layer_outputs[0]
#     532 if use_cache:
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:452, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     449     cross_attn_present_key_value = cross_attention_outputs[-1]
#     450     present_key_value = present_key_value + cross_attn_present_key_value
# --> 452 layer_output = apply_chunking_to_forward(
#     453     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     454 )
#     455 outputs = (layer_output,) + outputs
#     457 # if decoder, return the attn key/values as the last output
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/transformers/pytorch_utils.py:238, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     235     # concatenate output at same dimension
#     236     return torch.cat(output_chunks, dim=chunk_dim)
# --> 238 return forward_fn(*input_tensors)
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:464, in RobertaLayer.feed_forward_chunk(self, attention_output)
#     463 def feed_forward_chunk(self, attention_output):
# --> 464     intermediate_output = self.intermediate(attention_output)
#     465     layer_output = self.output(intermediate_output, attention_output)
#     466     return layer_output
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/share/envs/sarformer/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:363, in RobertaIntermediate.forward(self, hidden_states)
#     361 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
#     362     hidden_states = self.dense(hidden_states)
# --> 363     hidden_states = self.intermediate_act_fn(hidden_states)
#     364     return hidden_states
#
# TypeError: 'int' object is not callable
